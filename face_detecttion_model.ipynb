# %% [markdown]
# ## 1. Setup and Get Data

# %%
# !pip install labelme tensorflow tensorflow-gpu opencv-python matplotlib albumentations
# Out:
# Collecting labelme
#   Using cached labelme-5.8.1-py3-none-any.whl (1.4 MB)
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp310-cp310-win_amd64.whl (375.7 MB)
#      -------------------------------------- 375.7/375.7 MB 4.3 MB/s eta 0:00:00
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
#      ---------------------------------------- 39.5/39.5 MB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (3.10.1)
# Collecting albumentations
#   Downloading albumentations-2.0.6-py3-none-any.whl (332 kB)
#      -------------------------------------- 332.3/332.3 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from labelme) (6.0.2)
# Collecting imgviz
#   Downloading imgviz-1.7.6-py3-none-any.whl (7.7 MB)
#      ---------------------------------------- 7.7/7.7 MB 8.0 MB/s eta 0:00:00
# Collecting pyqt5>=5.14.0
#   Downloading PyQt5-5.15.11-cp38-abi3-win_amd64.whl (6.9 MB)
#      ---------------------------------------- 6.9/6.9 MB 8.9 MB/s eta 0:00:00
# Collecting scikit-image
#   Downloading scikit_image-0.25.2-cp310-cp310-win_amd64.whl (12.8 MB)
#      ---------------------------------------- 12.8/12.8 MB 8.0 MB/s eta 0:00:00
# Collecting natsort>=7.1.0
#   Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pillow>=2.8 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from labelme) (11.1.0)
# Collecting loguru
#   Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#      ---------------------------------------- 61.6/61.6 kB 1.7 MB/s eta 0:00:00
# Collecting pyqt5-qt5!=5.15.11,!=5.15.12,!=5.15.13,!=5.15.14,!=5.15.15,!=5.15.16
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#      ---------------------------------------- 50.1/50.1 MB 8.4 MB/s eta 0:00:00
# Collecting osam>=0.2.3
#   Downloading osam-0.2.3-py3-none-any.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from labelme) (2.2.3)
# Collecting tensorboard~=2.19.0
#   Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#      ---------------------------------------- 5.5/5.5 MB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (5.29.4)
# Collecting ml-dtypes<1.0.0,>=0.5.1
#   Downloading ml_dtypes-0.5.1-cp310-cp310-win_amd64.whl (209 kB)
#      ------------------------------------- 209.7/209.7 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in c:\users\ayush\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#      ---------------------------------------- 26.4/26.4 MB 8.5 MB/s eta 0:00:00
# Collecting termcolor>=1.1.0
#   Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Collecting keras>=3.5.0
#   Downloading keras-3.9.2-py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 9.5 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 9.4 MB/s eta 0:00:00
# Collecting absl-py>=1.0.0
#   Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
#      -------------------------------------- 135.6/135.6 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.32.3)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.5/57.5 kB 3.0 MB/s eta 0:00:00
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Collecting h5py>=3.11.0
#   Downloading h5py-3.13.0-cp310-cp310-win_amd64.whl (3.0 MB)
#      ---------------------------------------- 3.0/3.0 MB 9.9 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      ---------------------------------------- 71.9/71.9 kB ? eta 0:00:00
# Collecting flatbuffers>=24.3.25
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ayush\appdata\roaming\python\python310\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: setuptools in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (63.2.0)
# Collecting numpy
#   Downloading numpy-2.1.3-cp310-cp310-win_amd64.whl (12.9 MB)
#      ---------------------------------------- 12.9/12.9 MB 9.9 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.71.0-cp310-cp310-win_amd64.whl (4.3 MB)
#      ---------------------------------------- 4.3/4.3 MB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\ayush\appdata\roaming\python\python310\site-packages (from tensorflow) (24.2)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting python_version>"3.7"
#   Downloading python_version-0.0.2-py2.py3-none-any.whl (3.4 kB)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ayush\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Collecting opencv-python-headless>=4.9.0.80
#   Downloading opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl (39.4 MB)
#      ---------------------------------------- 39.4/39.4 MB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.10.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from albumentations) (1.15.2)
# Requirement already satisfied: pydantic>=2.9.2 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from albumentations) (2.11.4)
# Collecting albucore==0.0.24
#   Downloading albucore-0.0.24-py3-none-any.whl (15 kB)
# Collecting simsimd>=5.9.2
#   Downloading simsimd-6.2.1-cp310-cp310-win_amd64.whl (86 kB)
#      ---------------------------------------- 86.9/86.9 kB 5.1 MB/s eta 0:00:00
# Collecting stringzilla>=3.10.4
#   Downloading stringzilla-3.12.5-cp310-cp310-win_amd64.whl (80 kB)
#      ---------------------------------------- 80.1/80.1 kB 4.7 MB/s eta 0:00:00
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#      ---------------------------------------- 72.5/72.5 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: rich in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Collecting namex
#   Downloading namex-0.0.9-py3-none-any.whl (5.8 kB)
# Collecting optree
#   Downloading optree-0.15.0-cp310-cp310-win_amd64.whl (297 kB)
#      -------------------------------------- 297.3/297.3 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: click in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from osam>=0.2.3->labelme) (8.1.8)
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Collecting onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1
#   Downloading onnxruntime-1.22.0-cp310-cp310-win_amd64.whl (12.7 MB)
#      ---------------------------------------- 12.7/12.7 MB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2.9.2->albumentations) (0.4.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2.9.2->albumentations) (2.33.2)
# Collecting PyQt5-sip<13,>=12.15
#   Downloading PyQt5_sip-12.17.0-cp310-cp310-win_amd64.whl (59 kB)
#      ---------------------------------------- 59.0/59.0 kB ? eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Collecting markdown>=2.6.8
#   Downloading markdown-3.8-py3-none-any.whl (106 kB)
#      ---------------------------------------- 106.2/106.2 kB ? eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      -------------------------------------- 224.5/224.5 kB 6.9 MB/s eta 0:00:00
# Collecting win32-setctime>=1.0.0
#   Downloading win32_setctime-1.2.0-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\ayush\appdata\roaming\python\python310\site-packages (from loguru->labelme) (0.4.6)
# Collecting imageio!=2.35.0,>=2.33
#   Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
#      -------------------------------------- 315.8/315.8 kB 6.6 MB/s eta 0:00:00
# Collecting lazy-loader>=0.4
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Collecting networkx>=3.0
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 10.0 MB/s eta 0:00:00
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2025.5.10-py3-none-any.whl (226 kB)
#      ------------------------------------- 226.5/226.5 kB 13.5 MB/s eta 0:00:00
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.0/46.0 kB ? eta 0:00:00
# Collecting sympy
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ---------------------------------------- 6.3/6.3 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Collecting filelock
#   Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: tqdm in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from gdown->osam>=0.2.3->labelme) (4.67.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from gdown->osam>=0.2.3->labelme) (4.13.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ayush\appdata\roaming\python\python310\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->gdown->osam>=0.2.3->labelme) (2.7)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ---------------------------------------- 86.8/86.8 kB 5.1 MB/s eta 0:00:00
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      -------------------------------------- 536.2/536.2 kB 8.3 MB/s eta 0:00:00
# Collecting pyreadline3
#   Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
#      ---------------------------------------- 83.2/83.2 kB ? eta 0:00:00
# Using legacy 'setup.py install' for tensorflow-gpu, since package 'wheel' is not installed.
# Installing collected packages: stringzilla, simsimd, python_version, pyqt5-qt5, namex, mpmath, libclang, flatbuffers, win32-setctime, wheel, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorflow-gpu, tensorboard-data-server, sympy, PySocks, pyreadline3, PyQt5-sip, optree, opt-einsum, numpy, networkx, natsort, markdown, lazy-loader, grpcio, google-pasta, gast, filelock, absl-py, tifffile, tensorboard, pyqt5, opencv-python-headless, opencv-python, ml-dtypes, loguru, imageio, humanfriendly, h5py, astunparse, scikit-image, keras, gdown, coloredlogs, albucore, tensorflow, onnxruntime, imgviz, albumentations, osam, labelme
#   Running setup.py install for tensorflow-gpu: started
#   Running setup.py install for tensorflow-gpu: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for tensorflow-gpu did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\Ayush\AppData\Local\Temp\pip-install-7nifr6tc\tensorflow-gpu_ad41a34a0393414c98b27a6337b5fc10\setup.py", line 37, in <module>
#           raise Exception(TF_REMOVAL_WARNING)
#       Exception:
#
#       =========================================================
#       The "tensorflow-gpu" package has been removed!
#
#       Please install "tensorflow" instead.
#
#       Other than the name, the two packages have been identical
#       since TensorFlow 2.1, or roughly since Sep 2019. For more
#       information, see: pypi.org/project/tensorflow-gpu
#       =========================================================
#
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> tensorflow-gpu
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
#
# [notice] A new release of pip available: 22.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (2.2.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ##  2. WE WILL NOW COLLECT IMAGES

# %%
import os 
import time 
import uuid 
import cv2

# %%
images_path = os.path.join(  'data' , 'images' ) 
image_number = 30

# %%
cap = cv2.VideoCapture(0)

for i in range(image_number):
    print(f'Collecting image {i+1}')
    ret, frame = cap.read()
    imgname = os.path.join(images_path , f'{str(uuid.uuid1())}.jpg')
    cv2.imwrite(imgname , frame)
    cv2.imshow('frame' , frame) 
    time.sleep( 0.7) 

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting image 15
# Collecting image 16
# Collecting image 17
# Collecting image 18
# Collecting image 19
# Collecting image 20
# Collecting image 21
# Collecting image 22
# Collecting image 23
# Collecting image 24
# Collecting image 25
# Collecting image 26
# Collecting image 27
# Collecting image 28
# Collecting image 29
# Collecting image 30

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (22.2.1)
# Collecting pip
#   Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 9.7 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.2.1
#     Uninstalling pip-22.2.1:
#       Successfully uninstalled pip-22.2.1
# Successfully installed pip-25.1.1

# %%
# !pip install labelme==5.1.1
# Out:
# Collecting labelme==5.1.1
#   Downloading labelme-5.1.1.tar.gz (1.5 MB)
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ---------------------------- ----------- 1.0/1.5 MB 10.1 MB/s eta 0:00:01
#      ---------------------------- ----------- 1.0/1.5 MB 10.1 MB/s eta 0:00:01
#      ---------------------------- ----------- 1.0/1.5 MB 10.1 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: imgviz>=0.11 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from labelme==5.1.1) (1.7.6)
# Requirement already satisfied: matplotlib in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from labelme==5.1.1) (3.10.1)
# Requirement already satisfied: natsort>=7.1.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from labelme==5.1.1) (8.4.0)
# Requirement already satisfied: numpy in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from labelme==5.1.1) (2.2.3)
# Requirement already satisfied: Pillow>=2.8 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from labelme==5.1.1) (11.1.0)
# Requirement already satisfied: PyYAML in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from labelme==5.1.1) (6.0.2)
# Collecting qtpy!=1.11.2 (from labelme==5.1.1)
#   Downloading QtPy-2.4.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: termcolor in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from labelme==5.1.1) (3.1.0)
# Requirement already satisfied: colorama in c:\users\ayush\appdata\roaming\python\python310\site-packages (from labelme==5.1.1) (0.4.6)
# Requirement already satisfied: packaging in c:\users\ayush\appdata\roaming\python\python310\site-packages (from qtpy!=1.11.2->labelme==5.1.1) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->labelme==5.1.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->labelme==5.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->labelme==5.1.1) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->labelme==5.1.1) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->labelme==5.1.1) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ayush\appdata\roaming\python\python310\site-packages (from matplotlib->labelme==5.1.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ayush\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib->labelme==5.1.1) (1.17.0)
# Downloading QtPy-2.4.3-py3-none-any.whl (95 kB)
# Building wheels for collected packages: labelme
#   Building wheel for labelme (setup.py): started
#   Building wheel for labelme (setup.py): finished with status 'done'
#   Created wheel for labelme: filename=labelme-5.1.1-py3-none-any.whl size=1466368 sha256=2f631a9d48605345c8569bfb3102544432fef8d549c6c4fb081e3adc22335de1
#   Stored in directory: c:\users\ayush\appdata\local\pip\cache\wheels\53\ba\2c\7c69fef589562195d250277aac47b2a5822740fa63f9873e3b
# Successfully built labelme
# Installing collected packages: qtpy, labelme
#
#    ---------------------------------------- 0/2 [qtpy]
#    ---------------------------------------- 0/2 [qtpy]
#    ---------------------------------------- 0/2 [qtpy]
#    ---------------------------------------- 0/2 [qtpy]
#    ---------------------------------------- 0/2 [qtpy]
#    ---------------------------------------- 0/2 [qtpy]
#    ---------------------------------------- 0/2 [qtpy]
#    ---------------------------------------- 0/2 [qtpy]
#    ---------------------------------------- 0/2 [qtpy]
#    ---------------------------------------- 0/2 [qtpy]
#    ---------------------------------------- 0/2 [qtpy]
#   Attempting uninstall: labelme
#    ---------------------------------------- 0/2 [qtpy]
#     Found existing installation: labelme 5.8.1
#    ---------------------------------------- 0/2 [qtpy]
#     Uninstalling labelme-5.8.1:
#    ---------------------------------------- 0/2 [qtpy]
#       Successfully uninstalled labelme-5.8.1
#    ---------------------------------------- 0/2 [qtpy]
#    -------------------- ------------------- 1/2 [labelme]
#    -------------------- ------------------- 1/2 [labelme]
#    -------------------- ------------------- 1/2 [labelme]
#    -------------------- ------------------- 1/2 [labelme]
#    ---------------------------------------- 2/2 [labelme]
#
# Successfully installed labelme-5.1.1 qtpy-2.4.3
# WARNING: Ignoring invalid distribution -nnxruntime (c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages)
#   DEPRECATION: Building 'labelme' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'labelme'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# WARNING: Ignoring invalid distribution -nnxruntime (c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -nnxruntime (c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages)

# %% [markdown]
# ## LABEL THE DATA I.E. FACES USING LABEL ME

# %%
! labelme

# %% [markdown]
# ## BUILD AN IMAGE LOADING FUNCTION

# %%
! pip install  tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp310-cp310-win_amd64.whl.metadata (4.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (25.2.10)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (18.1.1)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\ayush\appdata\roaming\python\python310\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (63.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ayush\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ayush\appdata\roaming\python\python310\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.17.2)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.71.0-cp310-cp310-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.5.0 (from tensorflow)
#   Downloading keras-3.9.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting numpy<2.2.0,>=1.26.0 (from tensorflow)
#   Downloading numpy-2.1.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.13.0-cp310-cp310-win_amd64.whl.metadata (2.5 kB)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.1-cp310-cp310-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Collecting markdown>=2.6.8 (from tensorboard~=2.19.0->tensorflow)
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Collecting optree (from keras>=3.5.0->tensorflow)
#   Downloading optree-0.15.0-cp310-cp310-win_amd64.whl.metadata (49 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ayush\appdata\roaming\python\python310\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.19.0-cp310-cp310-win_amd64.whl (375.7 MB)
#    ---------------------------------------- 0.0/375.7 MB ? eta -:--:--
#    ---------------------------------------- 2.1/375.7 MB 9.8 MB/s eta 0:00:39
#    ---------------------------------------- 4.5/375.7 MB 10.3 MB/s eta 0:00:37
#     --------------------------------------- 6.8/375.7 MB 10.7 MB/s eta 0:00:35
#     --------------------------------------- 8.9/375.7 MB 10.4 MB/s eta 0:00:36
#    - -------------------------------------- 11.0/375.7 MB 10.4 MB/s eta 0:00:36
#    - -------------------------------------- 13.1/375.7 MB 10.3 MB/s eta 0:00:36
#    - -------------------------------------- 15.2/375.7 MB 10.2 MB/s eta 0:00:36
#    - -------------------------------------- 17.3/375.7 MB 10.2 MB/s eta 0:00:36
#    -- ------------------------------------- 19.4/375.7 MB 10.1 MB/s eta 0:00:36
#    -- ------------------------------------- 21.5/375.7 MB 10.1 MB/s eta 0:00:36
#    -- ------------------------------------- 23.6/375.7 MB 10.2 MB/s eta 0:00:35
#    -- ------------------------------------- 26.0/375.7 MB 10.2 MB/s eta 0:00:35
#    -- ------------------------------------- 28.0/375.7 MB 10.2 MB/s eta 0:00:35
#    --- ------------------------------------ 30.1/375.7 MB 10.2 MB/s eta 0:00:34
#    --- ------------------------------------ 32.5/375.7 MB 10.2 MB/s eta 0:00:34
#    --- ------------------------------------ 34.9/375.7 MB 10.3 MB/s eta 0:00:34
#    --- ------------------------------------ 36.4/375.7 MB 10.2 MB/s eta 0:00:34
#    ---- ----------------------------------- 38.5/375.7 MB 10.2 MB/s eta 0:00:34
MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 6.8 MB/s eta 0:00:00
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    --------------- ------------------------ 2.1/5.5 MB 11.8 MB/s eta 0:00:01
#    ------------------------------ --------- 4.2/5.5 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 9.6 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.13.0-cp310-cp310-win_amd64.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ---------------------------- ----------- 2.1/3.0 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.0/3.0 MB 9.6 MB/s eta 0:00:00
# Downloading keras-3.9.2-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 9.9 MB/s eta 0:00:00
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading optree-0.15.0-cp310-cp310-win_amd64.whl (297 kB)
# Installing collected packages: tensorboard-data-server, optree, opt-einsum, numpy, markdown, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, ml-dtypes, h5py, keras, tensorflow
#
#    -- -------------------------------------  1/15 [optree]
#    -- -------------------------------------  1/15 [optree]
#    ----- ----------------------------------  2/15 [opt-einsum]
#    ----- ----------------------------------  2/15 [opt-einsum]
#    ----- ----------------------------------  2/15 [opt-einsum]
#   Attempting uninstall: numpy
#    ----- ----------------------------------  2/15 [opt-einsum]
#     Found existing installation: numpy 2.2.3
#    ----- ----------------------------------  2/15 [opt-einsum]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#     Uninstalling numpy-2.2.3:
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#       Successfully uninstalled numpy-2.2.3
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    -------- -------------------------------  3/15 [numpy]
#    ---------- -----------------------------  4/15 [markdown]
#    ---------- -----------------------------  4/15 [markdown]
#    ---------- -----------------------------  4/15 [markdown]
#    ---------- -----------------------------  4/15 [markdown]
#    ---------- -----------------------------  4/15 [markdown]
#    ------------- --------------------------  5/15 [grpcio]
#    ------------- --------------------------  5/15 [grpcio]
#    ------------- --------------------------  5/15 [grpcio]
#    ------------- --------------------------  5/15 [grpcio]
#    ------------- --------------------------  5/15 [grpcio]
#    ------------- --------------------------  5/15 [grpcio]
#    ------------- --------------------------  5/15 [grpcio]
#    ---------------- -----------------------  6/15 [google-pasta]
#    ---------------- -----------------------  6/15 [google-pasta]
#    ---------------- -----------------------  6/15 [google-pasta]
#    ------------------ ---------------------  7/15 [gast]
#    ------------------------ ---------------  9/15 [absl-py]
#    ------------------------ ---------------  9/15 [absl-py]
#    ------------------------ ---------------  9/15 [absl-py]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------- ------------- 10/15 [tensorboard]
#    -------------------------------- ------- 12/15 [h5py]
#    -------------------------------- ------- 12/15 [h5py]
#    -------------------------------- ------- 12/15 [h5py]
#    -------------------------------- ------- 12/15 [h5py]
#    -------------------------------- ------- 12/15 [h5py]
#    -------------------------------- ------- 12/15 [h5py]
#    -------------------------------- ------- 12/15 [h5py]
#    -------------------------------- ------- 12/15 [h5py]
#    -------------------------------- ------- 12/15 [h5py]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ---------------------------------- ----- 13/15 [keras]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ------------------------------------- -- 14/15 [tensorflow]
#    ---------------------------------------- 15/15 [tensorflow]
#
# Successfully installed absl-py-2.2.2 astunparse-1.6.3 gast-0.6.0 google-pasta-0.2.0 grpcio-1.71.0 h5py-3.13.0 keras-3.9.2 markdown-3.8 ml-dtypes-0.5.1 numpy-2.1.3 opt-einsum-3.4.0 optree-0.15.0 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0
# WARNING: Ignoring invalid distribution -nnxruntime (c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -nnxruntime (c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Ayush\AppData\Local\Programs\Python\Python310\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Ayush\AppData\Local\Programs\Python\Python310\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
# WARNING: Ignoring invalid distribution -nnxruntime (c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import json
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.5 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 600, in run_forever
#     self._run_once()
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1896, in _run_once
#     handle._run()
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Ayush\AppData\Local\Temp\ipykernel_2472\313649447.py", line 1, in <module>
#     import tensorflow as tf
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\__init__.py", line 37, in <module>
#     from tensorflow.python.tools import module_util as _module_util
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\__init__.py", line 37, in <module>
#     from tensorflow.python.eager import context
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\context.py", line 35, in <module>
#     from tensorflow.python.client import pywrap_tf_session
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\client\pywrap_tf_session.py", line 19, in <module>
#     from tensorflow.python.client._pywrap_tf_session import *
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.5 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 600, in run_forever
#     self._run_once()
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1896, in _run_once
#     handle._run()
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Ayush\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Ayush\AppData\Local\Temp\ipykernel_2472\313649447.py", line 1, in <module>
#     import tensorflow as tf
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\__init__.py", line 37, in <module>
#     from tensorflow.python.tools import module_util as _module_util
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\__init__.py", line 42, in <module>
#     from tensorflow.python import data
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\__init__.py", line 21, in <module>
#     from tensorflow.python.data import experimental
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\experimental\__init__.py", line 96, in <module>
#     from tensorflow.python.data.experimental import service
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\experimental\service\__init__.py", line 419, in <module>
#     from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py", line 24, in <module>
#     from tensorflow.python.data.experimental.ops import compression_ops
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\experimental\ops\compression_ops.py", line 16, in <module>
#     from tensorflow.python.data.util import structure
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\util\structure.py", line 23, in <module>
#     from tensorflow.python.data.util import nest
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\util\nest.py", line 36, in <module>
#     from tensorflow.python.framework import sparse_tensor as _sparse_tensor
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\sparse_tensor.py", line 24, in <module>
#     from tensorflow.python.framework import constant_op
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\constant_op.py", line 25, in <module>
#     from tensorflow.python.eager import execute
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py", line 23, in <module>
#     from tensorflow.python.framework import dtypes
#   File "c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\dtypes.py", line 29, in <module>
#     from tensorflow.python.lib.core import _pywrap_bfloat16
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core._multiarray_umath failed to import
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.umath failed to import
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\__init__.py:37
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\__init__.py:42
#      37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
# ---> 42 from tensorflow.python import data
#      43 from tensorflow.python import distribute
#      44 # from tensorflow.python import keras
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\__init__.py:21
#      15 """`tf.data.Dataset` API for input pipelines.
#      16
#      17 See [Importing Data](https://tensorflow.org/guide/data) for an overview.
#      18 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\experimental\__init__.py:96
#      15 """Experimental API for building input pipelines.
#      16
#      17 This module contains experimental `Dataset` sources and transformations that can
#    (...)
#      92 @@UNKNOWN_CARDINALITY
#      93 """
#      95 # pylint: disable=unused-import
# ---> 96 from tensorflow.python.data.experimental import service
#      97 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\experimental\service\__init__.py:419
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """API for using the tf.data service.
#      16
#      17 This module contains:
#    (...)
#     416   job of ParameterServerStrategy).
#     417 """
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py:24
#      22 from tensorflow.python import tf2
#      23 from tensorflow.python.compat import compat
# ---> 24 from tensorflow.python.data.experimental.ops import compression_ops
#      25 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      26 from tensorflow.python.data.experimental.service import _pywrap_utils
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\experimental\ops\compression_ops.py:16
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Ops for compressing and uncompressing dataset elements."""
# ---> 16 from tensorflow.python.data.util import structure
#      17 from tensorflow.python.ops import gen_experimental_dataset_ops as ged_ops
#      20 def compress(element):
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\util\structure.py:23
#      20 import six
#      21 import wrapt
# ---> 23 from tensorflow.python.data.util import nest
#      24 from tensorflow.python.framework import composite_tensor
#      25 from tensorflow.python.framework import ops
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\util\nest.py:36
#      16 """## Functions for working with arbitrarily nested sequences of elements.
#      17
#      18 NOTE(mrry): This fork of the `tensorflow.python.util.nest` module
#    (...)
#      31    arrays.
#      32 """
#      34 import six as _six
# ---> 36 from tensorflow.python.framework import sparse_tensor as _sparse_tensor
#      37 from tensorflow.python.util import _pywrap_utils
#      38 from tensorflow.python.util import nest
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\sparse_tensor.py:24
#      22 from tensorflow.python import tf2
#      23 from tensorflow.python.framework import composite_tensor
# ---> 24 from tensorflow.python.framework import constant_op
#      25 from tensorflow.python.framework import dtypes
#      26 from tensorflow.python.framework import ops
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\constant_op.py:25
#      23 from tensorflow.core.framework import types_pb2
#      24 from tensorflow.python.eager import context
# ---> 25 from tensorflow.python.eager import execute
#      26 from tensorflow.python.framework import dtypes
#      27 from tensorflow.python.framework import op_callbacks
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:23
#      21 from tensorflow.python import pywrap_tfe
#      22 from tensorflow.python.eager import core
# ---> 23 from tensorflow.python.framework import dtypes
#      24 from tensorflow.python.framework import ops
#      25 from tensorflow.python.framework import tensor_shape
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\dtypes.py:34
#      31 from tensorflow.python.types import trace
#      32 from tensorflow.core.function import trace_type
# ---> 34 _np_bfloat16 = _pywrap_bfloat16.TF_bfloat16_type()
#      37 class DTypeMeta(type(_dtypes.DType), abc.ABCMeta):
#      38   pass
#
# TypeError: Unable to convert function return value to a Python type! The signature was
# 	() -> handle

# %%
# limit gpu usage 
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
# load images in the data pipeline 
images = tf.data.Dataset.list_files('data\\images\\*.jpg')

# %%
images.as_numpy_iterator().next()
# Out:
# 'data\\images\\4e919de3-3003-11f0-838e-581cf83e4c92.jpg'

# %%
## this funtion combines with the images.map ( ) 
# chanegs the image  file paths  stored as tensors  ( not the actual image data ) 
#  to the actual image tensors  , stored with the shape ( 256 , 256 , 3 ) for rgb images 

def load_image(x):
    image = tf.io.read_file(x)
    img2 = tf.io.decode_jpeg(image)
    return img2

# %%
images = images.map(load_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 images = images.map(load_image)
#
# NameError: name 'images' is not defined

# %%
images.as_numpy_iterator().next()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 images.as_numpy_iterator().next()
#
# NameError: name 'images' is not defined

# %%
type(images)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 type(images)
#
# NameError: name 'images' is not defined

# %%
## visula representation 

image_generator = images.batch(4).as_numpy_iterator() 
plot_images = image_generator.next() 

plt.figure(figsize=(10,13)) 
for i in range (4) : 
    plt.subplot(1, 4 , i+1)
    plt.imshow(plot_images[i])
    plt.title( f"image{i+1}")
    plt.axis("off")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[56], line 2
#       1 image_generator = images.batch(4).as_numpy_iterator()
# ----> 2 plot_images = image_generator.next()
#       4 plt.figure(figsize=(10,13))
#       5 for i in range (4) :
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4791, in NumpyIterator.next(self)
#    4790 def next(self):
# -> 4791   return self.__next__()
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4788, in NumpyIterator.__next__(self)
#    4785     numpy.setflags(write=False)
#    4786   return numpy
# -> 4788 return nest.map_structure(to_numpy, next(self._iterator))
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:826, in OwnedIterator.__next__(self)
#     824 def __next__(self):
#     825   try:
# --> 826     return self._next_internal()
#     827   except errors.OutOfRangeError:
#     828     raise StopIteration
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:776, in OwnedIterator._next_internal(self)
#     773 # TODO(b/77291417): This runs in sync mode as iterators use an error status
#     774 # to communicate that there is no more data to iterate over.
#     775 with context.execution_mode(context.SYNC):
# --> 776   ret = gen_dataset_ops.iterator_get_next(
#     777       self._iterator_resource,
#     778       output_types=self._flat_output_types,
#     779       output_shapes=self._flat_output_shapes)
#     781   try:
#     782     # Fast path for the case `self._structure` is not a nested structure.
#     783     return self._element_spec._from_compatible_tensor_list(ret)  # pylint: disable=protected-access
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3086, in iterator_get_next(iterator, output_types, output_shapes, name)
#    3084   return _result
#    3085 except _core._NotOkStatusException as e:
# -> 3086   _ops.raise_from_not_ok_status(e, name)
#    3087 except _core._FallbackException:
#    3088   pass
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:6006, in raise_from_not_ok_status(e, name)
#    6004 def raise_from_not_ok_status(e, name) -> NoReturn:
#    6005   e.message += (" name: " + str(name if name is not None else ""))
# -> 6006   raise core._status_to_exception(e) from None
#
# NotFoundError: {{function_node __wrapped__IteratorGetNext_output_types_1_device_/job:localhost/replica:0/task:0/device:CPU:0}} NewRandomAccessFile failed to Create/Open: data\images\2d8a2153-3003-11f0-ba25-581cf83e4c92.jpg : The system cannot find the file specified.
# ; No such file or directory
# 	 [[{{node ReadFile}}]] [Op:IteratorGetNext] name:

# %%
# now we move the matching labels  
for folder in ['train','test','val']:
    for file in os.listdir(os.path.join('data', folder, 'images')):
        
        filename = file.split('.')[0]+'.json'
        existing_filepath = os.path.join('data','labels', filename)
        if os.path.exists(existing_filepath): 
            new_filepath = os.path.join('data',folder,'labels',filename)
            os.replace(existing_filepath, new_filepath)

# %% [markdown]
# ## Apply Image Augmentation on Images and Labels using Albumentations

# %%
import albumentations as alb
import numpy as np

augmentor = alb.Compose([alb.RandomCrop(width=450, height=450), 
                         alb.HorizontalFlip(p=0.5), 
                         alb.RandomBrightnessContrast(p=0.2),
                         alb.RandomGamma(p=0.2), 
                         alb.RGBShift(p=0.2), 
                         alb.VerticalFlip(p=0.5)], 
                       bbox_params=alb.BboxParams(format='albumentations', 
                                                  label_fields=['class_labels']))

# %%
# load test images  and annotations  with open  cv  and json 
import os 
img = cv2.imread(os.path.join('data','train', 'images','2a8f6b31-3003-11f0-9e61-581cf83e4c92.jpg'))

# %%
import json

with open(os.path.join('data','train', 'labels','2a8f6b31-3003-11f0-9e61-581cf83e4c92.json') , 'r') as f : 
    label = json.load(f)

# %%
label['shapes'][0]['points']
# Out:
# [[377.1794871794872, 94.35897435897436],
#  [636.1538461538462, 410.2564102564103]]

# %%
# extract the coordinates  and rescale to match image resultion 
coords = [0 , 0 ,  0 , 0]

coords[0] = label['shapes'][0]['points'][0][0]
coords[1] = label['shapes'][0]['points'][0][1]
coords[2] = label['shapes'][0]['points'][1][0]
coords[3] = label['shapes'][0]['points'][1][1]

# %%
coords
# Out:
# [295.12820512820514, 53.333333333333336, 498.2051282051282, 341.02564102564105]

# %%
coords = list( np.divide( coords , [640 , 480 , 640 , 480 ]))

# %%
coords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 coords
#
# NameError: name 'coords' is not defined

# %%
## apply augmentations 
augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])

# %%
augmented
# Out:
# {'image': array([[[184, 160, 105],
#          [181, 157, 100],
#          [175, 151,  92],
#          ...,
#          [206, 177, 157],
#          [206, 177, 157],
#          [204, 177, 157]],
#
#         [[184, 160, 105],
#          [183, 158, 103],
#          [179, 155,  98],
#          ...,
#          [205, 176, 156],
#          [205, 176, 156],
#          [204, 177, 157]],
#
#         [[182, 160, 107],
#          [182, 158, 105],
#          [179, 155, 100],
#          ...,
#          [205, 176, 156],
#          [205, 176, 156],
#          [203, 176, 156]],
#
#         ...,
#
#         [[145, 123,  82],
#          [148, 125,  88],
#          [150, 126,  91],
#          ...,
#          [ 36,  19,  28],
#          [ 32,  17,  26],
#          [ 31,  14,  23]],
#
#         [[147, 123,  82],
#          [149, 127,  87],
#          [151, 128,  91],
#          ...,
#          [ 36,  22,  29],
#          [ 31,  19,  26],
#          [ 30,  16,  23]],
#
#         [[148, 124,  83],
#          [151, 126,  87],
#          [150, 127,  90],
#          ...,
#          [ 33,  21,  28],
#          [ 31,  19,  26],
#          [ 28,  16,  23]]], dtype=uint8),
#  'bboxes': [(0.4226210826210826,
#    0.2096866096866097,
#    0.9981196581196582,
#    0.9116809116809117)],
#  'class_labels': ['face']}

# %%
import matplotlib.pyplot as plt 
import cv2 

cv2.rectangle(augmented['image'], 
              tuple(np.multiply(augmented['bboxes'][0][:2], [450,450]).astype(int)),
              tuple(np.multiply(augmented['bboxes'][0][2:], [450,450]).astype(int)), 
              (200,0,0),2)


plt.imshow(augmented['image'])

# %%
# BUILD AND RUN AUGMENTATION PIPELINE 
for partition in ['train','test','val']: 
    for image in os.listdir(os.path.join('data', partition, 'images')):
        img = cv2.imread(os.path.join('data', partition, 'images', image))

        coords = [0,0,0.00001,0.00001]
        label_path = os.path.join('data', partition, 'labels', f'{image.split(".")[0]}.json')
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                label = json.load(f)

            coords[0] = label['shapes'][0]['points'][0][0]
            coords[1] = label['shapes'][0]['points'][0][1]
            coords[2] = label['shapes'][0]['points'][1][0]
            coords[3] = label['shapes'][0]['points'][1][1]
            coords = list(np.divide(coords, [640,480,640,480]))

        try: 
            for x in range(60):
                augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])
                cv2.imwrite(os.path.join('aug_data', partition, 'images', f'{image.split(".")[0]}.{x}.jpg'), augmented['image'])

                annotation = {}
                annotation['image'] = image

                if os.path.exists(label_path):
                    if len(augmented['bboxes']) == 0: 
                        annotation['bbox'] = [0,0,0,0]
                        annotation['class'] = 0 
                    else: 
                        annotation['bbox'] = augmented['bboxes'][0]
                        annotation['class'] = 1
                else: 
                    annotation['bbox'] = [0,0,0,0]
                    annotation['class'] = 0 


                with open(os.path.join('aug_data', partition, 'labels', f'{image.split(".")[0]}.{x}.json'), 'w') as f:
                    json.dump(annotation, f)

        except Exception as e:
            print(e)
# Out:
# x_max is less than or equal to x_min for bbox [0.13020833333333331, 0.3579059829059829, 0.0, 0.8985805860805861, 'face'].
# x_max is less than or equal to x_min for bbox [0.16626602564102566, 0.21794871794871795, 0.0, 0.833958446990362, 'face'].
# x_max is less than or equal to x_min for bbox [0.3529647435897436, 0.18162393162393162, 0.00921474358974359, 0.7809829059829061, 'face'].
# x_max is less than or equal to x_min for bbox [0.3834134615384615, 0.125, 0.04607371794871795, 0.9188034188034189, 'face'].
# x_max is less than or equal to x_min for bbox [0.9867788461538461, 0.2200854700854701, 0.8970352564102564, 0.826923076923077, 'face'].
# x_max is less than or equal to x_min for bbox [0.15504807692307693, 0.36004273504273504, -2.2204460492503132e-17, 0.9510003885003886, 'face'].
# x_max is less than or equal to x_min for bbox [0.2784455128205128, 0.1848290598290598, 0.002804487179487181, 0.716880341880342, 'face'].
# x_max is less than or equal to x_min for bbox [0.9891826923076923, 0.18803418803418806, 0.8032852564102564, 0.875, 'face'].

# %% [markdown]
# ## LOAD THE AUGMENTED IMAGES TO TENSORFLOW DATASET

# %%
import tensorflow as tf 
train_images = tf.data.Dataset.list_files('aug_data\\train\\images\\*.jpg', shuffle=False)
train_images = train_images.map(load_image)
train_images = train_images.map(lambda x: tf.image.resize(x, (120,120)))
train_images = train_images.map(lambda x: x/255)

# %%
test_images = tf.data.Dataset.list_files('aug_data\\test\\images\\*.jpg', shuffle=False)
test_images = test_images.map(load_image)
test_images = test_images.map(lambda x: tf.image.resize(x, (120,120)))
test_images = test_images.map(lambda x: x/255)

# %%
val_images = tf.data.Dataset.list_files('aug_data\\val\\images\\*.jpg', shuffle=False)
val_images = val_images.map(load_image)
val_images = val_images.map(lambda x: tf.image.resize(x, (120,120)))
val_images = val_images.map(lambda x: x/255)

# %%
val_image = next(iter(val_images))
print(val_image.shape)
val_images.as_numpy_iterator().next()
#  see the pixel values as a NumPy array
# Out:
# (120, 120, 3)
# array([[[0.5446078 , 0.7240196 , 0.748652  ],
#         [0.5425245 , 0.7124387 , 0.7477328 ],
#         [0.55588233, 0.7171569 , 0.75490195],
#         ...,
#         [0.41127452, 0.6818628 , 0.70637256],
#         [0.4127451 , 0.68333334, 0.7078431 ],
#         [0.41237745, 0.6859069 , 0.7058824 ]],
#
#        [[0.5377451 , 0.72205883, 0.75441176],
#         [0.54901963, 0.72156864, 0.75784314],
#         [0.5525122 , 0.7211397 , 0.75643384],
#         ...,
#         [0.4117647 , 0.6867647 , 0.69460785],
#         [0.41525736, 0.6906863 , 0.6903799 ],
#         [0.422549  , 0.69963235, 0.70324755]],
#
#        [[0.54295343, 0.72726715, 0.76648283],
#         [0.5396446 , 0.721201  , 0.7613358 ],
#         [0.54601717, 0.7275735 , 0.76770836],
#         ...,
#         [0.4009191 , 0.68811274, 0.7088848 ],
#         [0.41960785, 0.69803923, 0.7127451 ],
#         [0.42745098, 0.7019608 , 0.70980394]],
#
#        ...,
#
#        [[0.14264706, 0.24215686, 0.23333333],
#         [0.12242647, 0.23137255, 0.23627451],
#         [0.12843138, 0.24522059, 0.24650735],
#         ...,
#         [0.31856617, 0.58523285, 0.59699756],
#         [0.32892156, 0.5955882 , 0.5926471 ],
#         [0.31832108, 0.5908701 , 0.5889093 ]],
#
#        [[0.14105392, 0.23137255, 0.22530638],
#         [0.12990196, 0.23143382, 0.2357843 ],
#         [0.13713235, 0.23878677, 0.2439951 ],
#         ...,
#         [0.30778188, 0.5813113 , 0.5896446 ],
#         [0.32071078, 0.595098  , 0.5882966 ],
#         [0.3137255 , 0.58884805, 0.5856005 ]],
#
#        [[0.12561275, 0.21531862, 0.22279412],
#         [0.11752451, 0.22291666, 0.23645833],
#         [0.1411152 , 0.22248775, 0.24650735],
#         ...,
#         [0.3009804 , 0.5715686 , 0.59117645],
#         [0.31617647, 0.5932598 , 0.59724265],
#         [0.32254902, 0.595098  , 0.5980392 ]]], dtype=float32)

# %%
kakaji = train_images.as_numpy_iterator()

# %%
first_image2 = kakaji.next()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(3,3))
plt.imshow(first_image2) 
plt.axis('off')  # Hides axes
plt.title("First Image in Dataset")
plt.show()

# %%
import json

# %% [markdown]
# ##  BUILD A  LABEL LOADING FUNCTION

# %%
def load_labels(label_path):
    with open(label_path.numpy(), 'r', encoding = "utf-8") as f:
        label = json.load(f)
        #print( label)
        
    return [label['class']], label['bbox']

# %%
# Load Labels to Tensorflow Dataset
train_labels = tf.data.Dataset.list_files('aug_data\\train\\labels\\*.json', shuffle=False)
train_labels = train_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

test_labels = tf.data.Dataset.list_files('aug_data\\test\\labels\\*.json', shuffle=False)
test_labels = test_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

val_labels = tf.data.Dataset.list_files('aug_data\\val\\labels\\*.json', shuffle=False)
val_labels = val_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
for item in val_labels.take(4):
    label_class, bbox = item
 
    print("Class:", label_class.numpy(), "Shape:", label_class.shape)
    print( "\n")
    print("BBox:", bbox.numpy(), "Shape:", bbox.shape)
# Out:
# Class: [1] Shape: (1,)
#
#
# BBox: [0.1073 0.1063 0.635  0.743 ] Shape: (4,)
# Class: [1] Shape: (1,)
#
#
# BBox: [0.4673  0.07745 0.995   0.7144 ] Shape: (4,)
# Class: [1] Shape: (1,)
#
#
# BBox: [0.      0.11523 0.457   0.7524 ] Shape: (4,)
# Class: [1] Shape: (1,)
#
#
# BBox: [0.365   0.05743 0.8926  0.6943 ] Shape: (4,)

# %%
#for img in val_labels.take(1):
  #  print(type(img))         # <class 'tensorflow.python.framework.ops.EagerTensor'>
    #print(img.shape)         # TensorShape([120, 120, 3])

train_labels.as_numpy_iterator().next()
# Out:
# (array([1], dtype=uint8),
#  array([0.619 , 0.2112, 1.    , 0.862 ], dtype=float16))

# %% [markdown]
# ## Combine Label and Image Samples

# %%
# checking lengths 
len(train_images), len(train_labels), len(test_images), len(test_labels), len(val_images), len(val_labels)
# Out:
# (3540, 3540, 840, 840, 540, 540)

# %% [markdown]
# ## CREATING FINAL DATA SETS COMBINING IMAGES AND LABELS

# %%
train = tf.data.Dataset.zip(( train_images , train_labels) )
train = train.shuffle(5000)
train = train.batch(8)
train = train.prefetch(4)

# %%
for X, y in train.take(1):
    print("Class labels shape:", y[0].shape)
    print("Bounding boxes shape:", y[1].shape)
# Out:
# Class labels shape: (8, 1)
# Bounding boxes shape: (8, 4)

# %%
test = tf.data.Dataset.zip((test_images, test_labels))
test = test.shuffle(1300)
test = test.batch(8)
test = test.prefetch(4)

# %%
val = tf.data.Dataset.zip((val_images, val_labels))
val = val.shuffle(1000)
val = val.batch(8)
val = val.prefetch(4)

# %%
train.as_numpy_iterator().next()[1]
# Out:
# (array([[1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1]], dtype=uint8),
#  array([[0.7026 , 0.2101 , 1.     , 0.659  ],
#         [0.     , 0.1326 , 0.2778 , 0.862  ],
#         [0.6504 , 0.2715 , 1.     , 0.8516 ],
#         [0.     , 0.2627 , 0.3628 , 0.9053 ],
#         [0.     , 0.3206 , 0.1766 , 0.7354 ],
#         [0.     , 0.     , 0.     , 0.     ],
#         [0.6123 , 0.309  , 0.969  , 0.8286 ],
#         [0.05646, 0.3286 , 0.3882 , 0.901  ]], dtype=float16))

# %% [markdown]
# ## some visual examples

# %%
data_samples = train.as_numpy_iterator()

# %%
res = data_samples.next()

# %%
import cv2

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 5))

for i in range(4):
    img = res[0][i].copy()  # Make a writable copy
    bbox = res[1][1][i] 
    print(bbox )    # [x_min, y_min, x_max, y_max]

    # Scale bbox from normalized to pixel coordinates
    x1, y1, x2, y2 = (bbox * 120).astype(int)

    # Draw bounding box
    cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0,0), 2)

    ax[i].imshow(img)
    ax[i].axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# [0.5713 0.4895 0.8096 0.806 ]
# [0.525  0.2434 0.889  0.6924]
# [0.97   0.2983 1.     0.6606]
# [0.4072 0.0955 0.8438 0.681 ]

# %%
batch = train.as_numpy_iterator().next()
#print(batch[0])      # (8, 120, 120, 3)
print(batch[1][0][1])   # (8, 1) -> classes
print(batch[1][1][1])   # (8, 4) -> bboxes
# Out:
# {'image': '235f00d4-3003-11f0-9782-581cf83e4c92.jpg', 'bbox': [0.6189173789173789, 0.2111680911680911, 1.0, 0.8618803418803419], 'class': 1}
# {'image': '235f00d4-3003-11f0-9782-581cf83e4c92.jpg', 'bbox': [0.30558404558404556, 0.23783475783475772, 0.7614245014245015, 0.8885470085470085], 'class': 1}
# {'image': '235f00d4-3003-11f0-9782-581cf83e4c92.jpg', 'bbox': [0.41002849002849, 0.08923076923076924, 0.8658689458689458, 0.73994301994302], 'class': 1}
# {'image': '235f00d4-3003-11f0-9782-581cf83e4c92.jpg', 'bbox': [0.5322507122507122, 0.22894586894586888, 0.988091168091168, 0.8796581196581197], 'class': 1}
# {'image': '235f00d4-3003-11f0-9782-581cf83e4c92.jpg', 'bbox': [0.15190883190883198, 0.12923076923076923, 0.6077492877492878, 0.7799430199430201], 'class': 1}
# {'image': '235f00d4-3003-11f0-9782-581cf83e4c92.jpg', 'bbox': [0.6366951566951566, 0.22672364672364664, 1.0, 0.8774358974358974], 'class': 1}
# {'image': '235f00d4-3003-11f0-9782-581cf83e4c92.jpg', 'bbox': [0.0, 0.23339031339031335, 0.40997150997151, 0.884102564102564], 'class': 1}
# {'image': '235f00d4-3003-11f0-9782-581cf83e4c92.jpg', 'bbox': [0.3074643874643874, 0.22672364672364664, 0.7633048433048433, 0.8774358974358974], 'class': 1}
# {'image': '235f00d4-3003-11f0-9782-581cf83e4c92.jpg', 'bbox': [0.16301994301994305, 0.11589743589743591, 0.6188603988603989, 0.7666096866096866], 'class': 1}
# {'image': '235f00d4-3003-11f0-9782-581cf83e4c92.jpg', 'bbox': [0.08301994301994309, 0.0958974358974359, 0.5388603988603988, 0.7466096866096866], 'class': 1}
# {'image': '235f00d4-3003-11f0-9782-581cf83e4c92.jpg', 'bbox': [0.31635327635327637, 0.20227920227920215, 0.7721937321937322, 0.852991452991453], 'class': 1}
# {'image': '235f00d4-3003-11f0-9782-581cf83e4c92.jpg', 'bbox': [0.3766951566951567, 0.2489458689458689, 0.8325356125356125, 0.8996581196581197], 'class': 1}
# {'image': '55c69d3c-3003-11f0-a65f-581cf83e4c92.jpg', 'bbox': [0.7109401709401709, 0.1113960113960113, 1.0, 0.8407407407407408], 'class': 1}
# {'image': '55c69d3c-3003-11f0-a65f-581cf83e4c92.jpg', 'bbox': [0.5509401709401709, 0.14814814814814817, 1.0, 0.8774928774928776], 'class': 1}
# {'image': '55c69d3c-3003-11f0-a65f-581cf83e4c92.jpg', 'bbox': [0.0, 0.17703703703703705, 0.28017094017094024, 0.9063817663817665], 'class': 1}
# {'image': '55c69d3c-3003-11f0-a65f-581cf83e4c92.jpg', 'bbox': [0.602051282051282, 0.1637037037037037, 1.0, 0.8930484330484332], 'class': 1}
# {'image': '55c69d3c-3003-11f0-a65f-581cf83e4c92.jpg', 'bbox': [0.0, 0.1703703703703704, 0.19350427350427357, 0.8997150997150998], 'class': 1}
# {'image': '55c69d3c-3003-11f0-a65f-581cf83e4c92.jpg', 'bbox': [0.0, 0.14148148148148149, 0.1757264957264958, 0.8708262108262109], 'class': 1}
# {'image': '55c69d3c-3003-11f0-a65f-581cf83e4c92.jpg', 'bbox': [0.7109401709401709, 0.07806267806267797, 1.0, 0.8074074074074074], 'class': 1}
# [1]
# [0.214  0.2727 0.6016 0.9106]

# %% [markdown]
# ## NOW THE REAL THING
# ## BUILDING  OUR DEEP LEARINIG MODEL

# %%
#IMPORT LAYERS AND BASE 
from tensorflow.keras.models  import Model 
from tensorflow.keras.layers import Input, Conv2D, GlobalMaxPooling2DMaxPooling2D, Dense 
from tensorflow.keras.applications import VGG16 

#load the VGG16 model 
vgg = VGG16(include_top=False)
# Out:
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 6d6bbae143d832006294945121d1f1fc so we will re-download the data.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 21s 0us/step

# %%
vgg.summary()
from tensorflow.keras.layers import Input, Conv2D, GlobalMaxPooling2D, Dense
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# BUILDING INSTANCE OF A NETWOK 

def build_model():
    input_layer = Input(shape=(120,120,3))
    vgg = VGG16(include_top=False)(input_layer)

    # classification branch 
    f1 = GlobalMaxPooling2D( )(vgg)
    class1 = Dense(2048, activation='relu')(f1)
    class2 = Dense(1, activation='sigmoid')(class1)

    #regression branch 
    f2 = GlobalMaxPooling2D( )(vgg)
    regress1 = Dense(2048, activation='relu')(f2)
    regress2 = Dense(4, activation='sigmoid')(regress1)

    #combine branches 
    facetracker = Model( inputs = input_layer, outputs = [class2, regress2])
    #print(facetracker.summary())

    return facetracker

# %%
facetracker = build_model()
facetracker.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 120, 120, 3  0           []
#                                 )]
#
#  vgg16 (Functional)             (None, None, None,   14714688    ['input_8[0][0]']
#                                 512)
#
#  global_max_pooling2d_6 (Global  (None, 512)         0           ['vgg16[0][0]']
#  MaxPooling2D)
#
#  global_max_pooling2d_7 (Global  (None, 512)         0           ['vgg16[0][0]']
#  MaxPooling2D)
#
#  dense_12 (Dense)               (None, 2048)         1050624     ['global_max_pooling2d_6[0][0]']
#
#  dense_14 (Dense)               (None, 2048)         1050624     ['global_max_pooling2d_7[0][0]']
#
#  dense_13 (Dense)               (None, 1)            2049        ['dense_12[0][0]']
#
#  dense_15 (Dense)               (None, 4)            8196        ['dense_14[0][0]']
#
# ==================================================================================================
# Total params: 16,826,181
# Trainable params: 16,826,181
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
X , y = train.as_numpy_iterator().next()

# %%
classes, coords = facetracker.predict(X) 
print("Regression output shape:", coords.shape)  # Should be (batch_size, 4)
print("Regression label shape:", y[1].shape)     # Should match the above
# Out:
# 1/1 [==============================] - 0s 407ms/step
# Regression output shape: (8, 4)
# Regression label shape: (8, 4)

# %%
y[1]
# Out:
# array([[0.484  , 0.284  , 0.899  , 0.8574 ],
#        [0.0723 , 0.06384, 0.5337 , 0.7485 ],
#        [0.     , 0.     , 0.     , 0.     ],
#        [0.374  , 0.1724 , 0.8057 , 0.7363 ],
#        [0.61   , 0.11707, 0.9414 , 0.689  ],
#        [0.3398 , 0.3755 , 0.685  , 0.8516 ],
#        [0.641  , 0.09827, 1.     , 0.791  ],
#        [0.3494 , 0.2046 , 0.835  , 0.884  ]], dtype=float16)

# %%
coords
# Out:
# array([[0.4942596 , 0.25158897, 0.5691078 , 0.35136768],
#        [0.3711966 , 0.41368213, 0.5639871 , 0.3876482 ],
#        [0.34638262, 0.34966713, 0.4839373 , 0.38329414],
#        [0.45284665, 0.3526798 , 0.58589125, 0.41702548],
#        [0.34652185, 0.3584453 , 0.5808687 , 0.4164907 ],
#        [0.43916214, 0.2756384 , 0.6252442 , 0.36458445],
#        [0.2854094 , 0.29591265, 0.40348783, 0.3167649 ],
#        [0.47624376, 0.34184557, 0.5674012 , 0.38358676]], dtype=float32)

# %%
len( train )
# Out:
# 3544

# %% [markdown]
# ## DEFINE LOSSES AND OPTIMISE

# %%
batches_per_epoch = len(train)
lr_decay = (1./0.75 -1)/batches_per_epoch

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0001, decay=lr_decay)

# %%
# CREATING THE LOSS FUNCTION 

def localization_loss(y_true, y_hat):
    delta_coord =     tf.reduce_sum(tf.square( y_true[: ,:2]- y_hat[: , :2]))

    h_true = y_true[: , 3] - y_true[: , 1] 
    w_true = y_true[: , 2] - y_true[: , 0 ]

    h_pred = y_hat[: , 3] - y_hat[: , 1]
    w_pred = y_hat[: , 2] - y_hat[: , 0]

    delta_size =    tf.reduce_sum(tf.square((w_true - w_pred))+ tf.square( h_true - h_pred))


    return delta_coord + delta_size

# %%
def classloss(y_true, y_hat):
    return tf.keras.losses.binary_crossentropy(y_true, y_hat)

regressloss = localization_loss

# %%
regressloss(y[1], coords)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.6377568>

# %%
classloss(y[0], classes)
# Out:
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([0.4787492 , 0.43888792, 0.9318838 , 0.53489625, 0.52554524,
#        0.43426433, 0.39291126, 0.48960936], dtype=float32)>

# %% [markdown]
# ## TRAIN THE NEURAL NETWORK

# %%
class FaceTracker(Model): 
    def __init__(self, eyetracker,  **kwargs): 
        super().__init__(**kwargs)
        self.model = eyetracker

    def compile(self, opt, classloss, localizationloss, **kwargs):
        super().compile(**kwargs)
        self.closs = classloss
        self.lloss = localizationloss
        self.opt = opt
    
    def train_step(self, batch, **kwargs): 
        
        X, y = batch
        
        with tf.GradientTape() as tape: 
            classes, coords = self.model(X, training=True)
            
            batch_classloss = self.closs(y[0], classes)
            batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
            
            total_loss = batch_localizationloss+0.5*batch_classloss
            
            grad = tape.gradient(total_loss, self.model.trainable_variables)
        
        opt.apply_gradients(zip(grad, self.model.trainable_variables))
        
        return {"total_loss":total_loss, "class_loss":batch_classloss, "regress_loss":batch_localizationloss}
    
    def test_step(self, batch, **kwargs): 
        X, y = batch
        
        classes, coords = self.model(X, training=False)
        
        batch_classloss = self.closs(y[0], classes)
        batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
        total_loss = batch_localizationloss+0.5*batch_classloss
        
        return {"total_loss":total_loss, "class_loss":batch_classloss, "regress_loss":batch_localizationloss}
        
    def call(self, X, **kwargs): 
        return self.model(X, **kwargs)

# %%
model = FaceTracker(facetracker)

# %%
model.compile(opt, classloss, regressloss)

# %% [markdown]
# TRAIN

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
# !pip install --upgrade tensorflow tensorboard
# Out:
# Requirement already satisfied: tensorflow in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (2.10.1)
# WARNING: Ignoring invalid distribution -nnxruntime (c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -nnxruntime (c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Ayush\AppData\Local\Programs\Python\Python310\Lib\site-packages\google\~rotobuf'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Ayush\AppData\Local\Programs\Python\Python310\Lib\site-packages\~=mpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Ayush\AppData\Local\Programs\Python\Python310\Lib\site-packages\tensorflow\compiler\~f2tensorrt'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Ayush\AppData\Local\Programs\Python\Python310\Lib\site-packages\tensorflow\lite\~-perimental'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Ayush\AppData\Local\Programs\Python\Python310\Lib\site-packages\tensorflow\lite\~ython'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Ayush\AppData\Local\Programs\Python\Python310\Lib\site-packages\tensorflow\~-thon'.
#   You can safely remove it manually.
# WARNING: Ignoring invalid distribution -nnxruntime (c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.10.1 requires numpy<1.27.0,>=1.19.5, but you have numpy 2.1.3 which is incompatible.
# streamlit 1.44.1 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.
# Collecting tensorflow
#   Using cached tensorflow-2.19.0-cp310-cp310-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: tensorboard in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (2.10.1)
# Collecting tensorboard
#   Using cached tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow)
#   Downloading protobuf-5.29.4-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (63.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ayush\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ayush\appdata\roaming\python\python310\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.71.0)
# Collecting keras>=3.5.0 (from tensorflow)
#   Using cached keras-3.9.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting numpy<2.2.0,>=1.26.0 (from tensorflow)
#   Using cached numpy-2.1.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorboard) (3.8)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ayush\appdata\roaming\python\python310\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ayush\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Using cached tensorflow-2.19.0-cp310-cp310-win_amd64.whl (375.7 MB)
# Using cached tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
# Using cached numpy-2.1.3-cp310-cp310-win_amd64.whl (12.9 MB)
# Downloading protobuf-5.29.4-cp310-abi3-win_amd64.whl (434 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached keras-3.9.2-py3-none-any.whl (1.3 MB)
# Installing collected packages: tensorboard-data-server, protobuf, numpy, tensorboard, keras, tensorflow
#
#   Attempting uninstall: tensorboard-data-server
#
#     Found existing installation: tensorboard-data-server 0.6.1
#
#     Uninstalling tensorboard-data-server-0.6.1:
#
#       Successfully uninstalled tensorboard-data-server-0.6.1
#
#   Attempting uninstall: protobuf
#
#     Found existing installation: protobuf 3.19.6
#
#     Uninstalling protobuf-3.19.6:
#
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#       Successfully uninstalled protobuf-3.19.6
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#   Attempting uninstall: numpy
#    ------ --------------------------------- 1/6 [protobuf]
#     Found existing installation: numpy 1.23.5
#    ------ --------------------------------- 1/6 [protobuf]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#     Uninstalling numpy-1.23.5:
#    ------------- -------------------------- 2/6 [numpy]
#       Successfully uninstalled numpy-1.23.5
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#   Attempting uninstall: tensorboard
#    ------------- -------------------------- 2/6 [numpy]
#     Found existing installation: tensorboard 2.10.1
#    ------------- -------------------------- 2/6 [numpy]
#    -------------------- ------------------- 3/6 [tensorboard]
#     Uninstalling tensorboard-2.10.1:
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#       Successfully uninstalled tensorboard-2.10.1
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------- ------------------- 3/6 [tensorboard]
#   Attempting uninstall: keras
#    -------------------- ------------------- 3/6 [tensorboard]
#     Found existing installation: keras 2.10.0
#    -------------------- ------------------- 3/6 [tensorboard]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#     Uninstalling keras-2.10.0:
#    -------------------------- ------------- 4/6 [keras]
#       Successfully uninstalled keras-2.10.0
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#    -------------------------- ------------- 4/6 [keras]
#   Attempting uninstall: tensorflow
#    -------------------------- ------------- 4/6 [keras]
#     Found existing installation: tensorflow 2.10.1
#    -------------------------- ------------- 4/6 [keras]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#     Uninstalling tensorflow-2.10.1:
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#       Successfully uninstalled tensorflow-2.10.1
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    --------------------------------- ------ 5/6 [tensorflow]
#    ---------------------------------------- 6/6 [tensorflow]
#
# Successfully installed keras-3.9.2 numpy-2.1.3 protobuf-5.29.4 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0

# %%
hist = model.fit(
    train.take(10), 
    epochs=1, 
    validation_data=val, 
    callbacks=[tensorboard_callback]
)
'''
for metric_name, metric_value in hist.history.items():
    print(f"{metric_name}: {metric_value}")
'''
# Out:
# 10/10 [==============================] - ETA: 0s - total_loss: 0.0479 - class_loss: 0.0041 - regress_loss: 0.0459
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 hist = model.fit(
#       2     train.take(10),
#       3     epochs=1,
#       4     validation_data=val,
#       5     callbacks=[tensorboard_callback]
#       6 )
#       7 '''
#       8 for metric_name, metric_value in hist.history.items():
#       9     print(f"{metric_name}: {metric_value}")
#      10 '''
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\Ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorboard\plugins\scalar\summary_v2.py:88, in scalar(name, data, step, description)
#      83 summary_scope = (
#      84     getattr(tf.summary.experimental, "summary_scope", None)
#      85     or tf.summary.summary_scope
#      86 )
#      87 with summary_scope(name, "scalar_summary", values=[data, step]) as (tag, _):
# ---> 88     tf.debugging.assert_scalar(data)
#      89     return tf.summary.write(
#      90         tag=tag,
#      91         tensor=tf.cast(data, tf.float32),
#      92         step=step,
#      93         metadata=summary_metadata,
#      94     )
#
# ValueError: Expected scalar shape, saw shape: (4,).
